# %%
# Function is a block of code only run when you call it.
def function():
    print("My First Function")
function()
# Out:
# My First Function

# %%
def number_squared(num):
    print(num*num)

number_squared(5)
# Out:
# 25

# %%
def number_squared(num,pow):
    print(num**pow)

num=int(input())
pow=int(input())
number_squared(num,pow)
# Out:
#  5
#  2
# 25

# %%
def number_args(*number):
    print(number[0]*number[1])

number_args(1,5,6,7,8,9)
# Out:
# 5

# %%
args_tuple=(5,4,3,2,7,8,9)
def number_args(*number):
    print(number[0]*number[1])

number_args(*args_tuple)
# Out:
# 20

# %%
def number_squared(num,pow):
    print(num**pow)

number_squared(pow=5,num=3)
# Out:
# 243

# %%
def number_kwargs(**number):
    print('My number is:'+number['integer']+' my other number is:'+number['integer2'])

number_kwargs(integer='2309',integer2='349')
# Out:
# My number is:2309 my other number is:349
