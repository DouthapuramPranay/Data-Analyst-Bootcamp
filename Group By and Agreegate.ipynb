# %%
import pandas as pd
# Out:
# C:\Users\douth\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.8.7' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\douth\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:56: UserWarning: Pandas requires version '1.4.2' or newer of 'bottleneck' (version '1.3.7' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv(r"C:\Users\douth\Downloads\Flavors.csv")
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
group_by_frame = df.groupby('Base Flavor')[['Flavor Rating', 'Texture Rating', 'Total Rating']]

# %%
group_by_frame.mean()
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
group_by_frame.sum()
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate             25.2            21.7          47.1
# Vanilla               34.2            33.9          68.1

# %%
group_by_frame.min()
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.2             7.0          15.2
# Vanilla                2.3             3.4           5.7

# %%
group_by_frame.max()
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.8             7.6          16.6
# Vanilla               10.0             8.0          18.0

# %%
group_by_frame.count()
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate                3               3             3
# Vanilla                  6               6             6

# %%
df.groupby('Base Flavor').agg({
    'Flavor Rating': ['mean', 'count', 'sum'],
    'Texture Rating': ['mean', 'count', 'sum']
})
# Out:
#             Flavor Rating             Texture Rating
#                      mean count   sum           mean count   sum
# Base Flavor
# Chocolate             8.4     3  25.2       7.233333     3  21.7
# Vanilla               5.7     6  34.2       5.650000     6  33.9

# %%
df.groupby(['Base Flavor','Liked'])[['Flavor Rating','Texture Rating']].mean()
# Out:
#                    Flavor Rating  Texture Rating
# Base Flavor Liked
# Chocolate   Yes              8.4        7.233333
# Vanilla     No               3.6        4.466667
#             Yes              7.8        6.833333

# %%
df.groupby('Base Flavor','Liked').agg({
    'Flavor Rating': ['mean', 'count', 'sum'],
    'Texture Rating': ['mean', 'count', 'sum']
})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 df.groupby('Base Flavor','Liked').agg({
#       2     'Flavor Rating': ['mean', 'count', 'sum'],
#       3     'Texture Rating': ['mean', 'count', 'sum']
#       4 })
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
# ...
